# %% [markdown]
# Initialization and imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
sns.set()

data = pd.read_csv("test (3).csv")
print(data.head())
# Out:
#    id  battery_power  blue  clock_speed  ...  talk_time  three_g  touch_screen  wifi
# 0   1           1043     1          1.8  ...          2        0             1     0
# 1   2            841     1          0.5  ...          7        1             0     0
# 2   3           1807     1          2.8  ...         10        0             1     1
# 3   4           1546     0          0.5  ...          7        1             1     0
# 4   5           1434     0          1.4  ...          7        1             0     1
#
# [5 rows x 21 columns]

# %% [markdown]
# Correlation between objects

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", linecolor='white', linewidths=1)

# %% [markdown]
# Standardizing the data set and dividing it into 80% training and 20% testing:

# %%
x = data.iloc[:, :-10].values
y = data.iloc[:, -3].values
x = StandardScaler().fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=26, random_state=100)

# %% [markdown]
# LogReg()

# %%
from sklearn.linear_model import LogisticRegression
lreg = LogisticRegression()
lreg.fit(x_train, y_train)
y_pred = lreg.predict(x_test)

# %% [markdown]
# Model accuracy

# %%
accuracy = accuracy_score(y_test, y_pred) * 100
print("Accuracy of the Logistic Regression Model: ",accuracy)
# Out:
# Accuracy of the Logistic Regression Model:  96.15384615384616
